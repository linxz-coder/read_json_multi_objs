# %%
import json

# 打开JSON文件并读取内容
with open('/Users/lxz/Desktop/json/MOOCCube/additional_information/test.json', 'r') as file:
    json_data = file.read()

# 解析JSON数据
data = json.loads(json_data)

# %%
data
# Out:
# {'id': 'U_8126464',
#  'activity': [{'course_id': 'C_course-v1:TsinghuaX+00740123_X+sp',
#    'video_id': 'V_00990e1b22984f2f98f403475efb5548',
#    'watching_count': 3,
#    'video_duration': 351,
#    'local_watching_time': 107,
#    'video_progress_time': 133.09999704360962,
#    'video_start_time': 0,
#    'video_end_time': 351,
#    'local_start_time': '2019-02-10 09:11:48',
#    'local_end_time': '2019-02-10 09:13:35'},
#   {'course_id': 'C_course-v1:TsinghuaX+00740123X+2019_T1',
#    'video_id': 'V_00990e1b22984f2f98f403475efb5548',
#    'watching_count': 3,
#    'video_duration': 351,
#    'local_watching_time': 107,
#    'video_progress_time': 133.09999704360962,
#    'video_start_time': 0,
#    'video_end_time': 351,
#    'local_start_time': '2019-02-10 09:11:48',
#    'local_end_time': '2019-02-10 09:13:35'},
#   {'course_id': 'C_course-v1:TsinghuaX+00740123_X+sp',
#    'video_id': 'V_01cfd78003d648138fae23b5c14b2416',
#    'watching_count': 5,
#    'video_duration': 381,
# ...

# %%
import json

# 打开JSON文件并读取内容
with open('data.json', 'r') as file:
    json_data = file.read()

# 解析JSON数据
data = json.loads(json_data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[3], line 8
#       5     json_data = file.read()
#       7 # 解析JSON数据
# ----> 8 data = json.loads(json_data)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# ...

# %%
import json

with open('data.json', 'r') as file:
    text = file.read()

objs = text.splitlines()
print(len(objs))
# Out:
# 48640

# %%
print(objs[1])
# Out:
# {"id": "U_8650752", "activity": [{"course_id": "C_course-v1:TsinghuaX+00740043X_2015_T2+sp", "video_id": "V_00a75596b54a48778482dc8cd002d3c4", "watching_count": 12, "video_duration": 419.0, "local_watching_time": 386, "video_progress_time": 475.3400101661682, "video_start_time": 0.0, "video_end_time": 419.0, "local_start_time": "2018-03-14 19:45:45", "local_end_time": "2018-03-14 20:00:36"}, {"course_id": "C_course-v1:TsinghuaX+30640014X+sp", "video_id": "V_011003392bc342578883877198a6c2dd", "watching_count": 5, "video_duration": 507.0, "local_watching_time": 565, "video_progress_time": 589.0229949951173, "video_start_time": 0.0, "video_end_time": 507.0, "local_start_time": "2018-03-11 23:33:47", "local_end_time": "2018-03-12 19:36:10"}, {"course_id": "C_course-v1:TsinghuaX+00740043X_2015_T2+sp", "video_id": "V_021e36f80cd446ad831fb27081ec973f", "watching_count": 2, "video_duration": 202.0, "local_watching_time": 162, "video_progress_time": 201.8800048828125, "video_start_time": 0.0,
# ...

# %%
#转换成字典
for item in objs:
    data = json.loads(item)
    print(data["activity"][0]["local_watching_time"])
# Out:
# 107
# 386
# 43
# 846
# 33
# 728
# 6
# 197
# 367
# 1201
# 1457
# 790
# 408
# 498
# 213
# 44
# 50
# 1625
# 148
# 454
# 77
# 128
# 72
# 522
# 279
# 315
# 348
# 4961
# 427
# 2334
# 511
# 55
# 240
# 187
# 280
# 91
# 232
# 663
# 1194
# 52
# 307
# 362
# 295
# 2025
# 1436
# 943
# 1176
# 1143
# 348
# 34
# 13
# 225
# 701
# 172
# 561
# 387
# 13
# 202
# 247
# 12
# 5
# 329
# 421
# 20
# 475
# 2131
# 775
# 10
# 1638
# 455
# 377
# 581
# 230
# 129
# 939
# 249
# 4
# 20
# 8
# 223
# 352
# 20
# 46
# 18
# 617
# 430
# 1032
# 13632
# 405
# 586
# 308
# 192
# 475
# 125
# 126
# 106
# 248
# 1273
# 60
# 429
# 23
# 137
# 624
# 1213
# 62
# 7
# 2445
# 702
# 342
# 662
# 87
# 520
# 460
# 119
# 32
# 512
# 238
# 220
# 384
# 156
# 325
# 237
# 28
# 439
# 167
# 650
# 708
# 1
# 178
# 413
# 290
# 71
# 16
# 1756
# 231
# 660
# 580
# 388
# 602
# 27
# 408
# 191
# 1115
# 952
# 867
# 1013
# 810
# 362
# 651
# 378
# 270
# 362
# 4786
# 93
# 914
# 251
# 1085
# 14
# 14
# 558
# 564
# 291
# 430
# 210
# 95
# 43
# 2520
# 548
# 12
# 1307
# ...
